# %%
import pandas as pd
flight_details_table = pd.read_csv("../data/flight-detail-grouped.csv")
flight_details_table.drop(columns='Unnamed: 0')
# Out:
#      flight.number airline.name arrival.iataCode departure.iataCode  \
# 0                5         azul              afl                gyn
# 1             1144          gol              cgr                gru
# 2             1226          gol              cgr                cgh
# 3             1348          gol              cgr                gru
# 4             1414          gol              cgr                gru
# ..             ...          ...              ...                ...
# 360           9358          klm              cgr                gig
# 361           9378          klm              cgr                gru
# 362           9382          klm              cgr                gru
# 363           9557          gol              cgr                poa
# 364           9655          gol              cgr                gru
#
#      flight_duration_min
# 0             103.000000
# 1              55.000000
# 2              50.263158
# 3              54.469697
# 4              54.166667
# ..                   ...
# 360            85.000000
# 361            55.000000
# 362            55.000000
# 363            70.000000
# 364            40.000000
#
# [365 rows x 5 columns]

# %%
flight_details_table.dtypes
# Out:
# Unnamed: 0               int64
# flight.number            int64
# airline.name            object
# arrival.iataCode        object
# departure.iataCode      object
# flight_duration_min    float64
# dtype: object

# %%
flight_number = 1960

# %%
bool_mask = flight_details_table['flight.number'] == 1960
flight_details_table[bool_mask]
# Out:
#     Unnamed: 0  flight.number airline.name arrival.iataCode  \
# 21          21           1960   air france              aju
#
#    departure.iataCode  flight_duration_min
# 21                gru                160.0

# %%
flight_detail = flight_details_table.loc[flight_details_table['flight.number'] == flight_number].copy()
flight_detail
# Out:
#     Unnamed: 0  flight.number airline.name arrival.iataCode  \
# 21          21           1960   air france              aju
#
#    departure.iataCode  flight_duration_min
# 21                gru                160.0

# %%
city_details_table = pd.read_csv("../data/output_passengers.csv",encoding='UTF-8')
city_details_table
# Out:
#       year  city_code              city_name city_cluster_type_grouped  \
# 0     2023    1100015  Alta Floresta D'Oeste              Centro Local
# 1     2023    1100023              Ariquemes       Centro Sub-Regional
# 2     2023    1100031                 Cabixi              Centro Local
# 3     2023    1100049                 Cacoal          Capital Regional
# 4     2023    1100056             Cerejeiras            Centro de Zona
# ...    ...        ...                    ...                       ...
# 5565  2023    5222005             Vianópolis              Centro Local
# 5566  2023    5222054         Vicentinópolis              Centro Local
# 5567  2023    5222203               Vila Boa              Centro Local
# 5568  2023    5222302          Vila Propício              Centro Local
# 5569  2023    5300108               Brasília                 Metrópole
#
#       GDP_agrobusiness_(BRL1000)  GDP_industrials_(BRL1000)  \
# 0                       327237.0                    29257.0
# 1                       307834.0                   426899.0
# 2                       143578.0                     8526.0
# 3                       358594.0                   248706.0
# 4                       159369.0                    28799.0
# ...                          ...                        ...
# 5565                    436930.0                    46115.0
# 5566                    204522.0                    92102.0
# 5567                     61372.0                    31808.0
# 5568                    165945.0                    60245.0
# 5569                   2402725.0                 10753661.0
#
#       GDP_services_(BRL1000)  GDP_public_sector_spend_(BRL1000)  \
# 0                   181165.0                           181886.0
# 1                  1374144.0                           821911.0
# 2                    37681.0                            48937.0
# 3                  1261412.0                           660958.0
# 4                   324293.0                           129610.0
# ...                      ...                                ...
# 5565                269400.0                            79557.0
# 5566                119052.0                            55292.0
# 5567                 42346.0                            38571.0
# 5568                 49089.0                            34810.0
# 5569             134161390.0                        122722664.0
#
#       GDP_per_capita_year  region_id  ... population_size_2012  \
# 0                 34272.0          1  ...              24516.0
# 1                 30340.0          1  ...              95836.0
# 2                 49434.0          1  ...               6207.0
# 3                 33949.0          1  ...              81487.0
# 4                 48525.0          1  ...              17182.0
# ...                   ...        ...  ...                  ...
# 5565              63985.0          5  ...              13019.0
# 5566              56042.0          5  ...               7783.0
# 5567              29299.0          5  ...               5124.0
# 5568              54470.0          5  ...               5369.0
# 5569              97426.0          5  ...            2722198.0
#
#                metropolitan_area metropolitan_area_code  passengers  \
# 0                         Cacoal                 110005         NaN
# 1                      Ariquemes                 110002         NaN
# 2                        Vilhena                 110006         NaN
# 3                         Cacoal                 110005     41162.0
# 4                        Vilhena                 110006         NaN
# ...                          ...                    ...         ...
# 5565                    Anápolis                 520002         NaN
# 5566                 Piracanjuba                 520009         NaN
# 5567             Flores de Goiás                 520022         NaN
# 5568  Ceres - Rialma - Goianésia                 520018         NaN
# 5569            Distrito Federal                 530001  14274501.0
#
#      latitude_radian  longitude_radian  count_airports  \
# 0          -0.208188         -1.082022             0.0
# 1          -0.172887         -1.100125             0.0
# 2          -0.235523         -1.056832             0.0
# 3          -0.199566         -1.072613             1.0
# 4          -0.230157         -1.061453             0.0
# ...              ...               ...             ...
# 5565       -0.292177         -0.846762             0.0
# 5566       -0.309485         -0.869256             0.0
# 5567       -0.262475         -0.821212             0.0
# 5568       -0.269727         -0.853150             0.0
# 5569       -0.275404         -0.836531             1.0
#
#       total_airports_surronding_metrop_region  metropolitan_area_km2  \
# 0                                         1.0              36166.460
# 1                                         0.0              23260.950
# 2                                         1.0              31449.639
# 3                                         1.0              36166.460
# 4                                         1.0              31449.639
# ...                                       ...                    ...
# 5565                                      0.0              14607.338
# 5566                                      0.0               6551.396
# 5567                                      0.0              20434.362
# 5568                                      0.0              20174.300
# 5569                                      1.0               5760.784
#
#       predicted_passengers
# 0                  11117.0
# 1                  23005.0
# 2                  11117.0
# 3                      NaN
# 4                    429.0
# ...                    ...
# 5565                5929.0
# 5566                3219.0
# 5567                1027.0
# 5568                3812.0
# 5569                   NaN
#
# [5570 rows x 23 columns]

# %%
city_details_table.dtypes
# Out:
# year                                         int64
# city_code                                    int64
# city_name                                   object
# city_cluster_type_grouped                   object
# GDP_agrobusiness_(BRL1000)                 float64
# GDP_industrials_(BRL1000)                  float64
# GDP_services_(BRL1000)                     float64
# GDP_public_sector_spend_(BRL1000)          float64
# GDP_per_capita_year                        float64
# region_id                                    int64
# region_name                                 object
# state_id                                     int64
# state_name                                  object
# population_size_2012                       float64
# metropolitan_area                           object
# metropolitan_area_code                       int64
# passengers                                 float64
# latitude_radian                            float64
# longitude_radian                           float64
# count_airports                             float64
# total_airports_surronding_metrop_region    float64
# metropolitan_area_km2                      float64
# predicted_passengers                       float64
# dtype: object
